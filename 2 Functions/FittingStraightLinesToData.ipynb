# %% [markdown]
# # Fitting linear functions to data #
#
# This module demonstrates the error generated after providing specimen values to `a` and `b` in `y = ax + b` and then plots the linear function with `a` and `b` alongside the gathered data.

# %%
import matplotlib.pyplot as plt
import numpy as np

def lin(t, a, b):
    return a*t + b


#Fitting straight line data (x and y are lists)
def fit(x, y):
    # a = float(input("Enter a value for a: "))
    # b = float(input("Enter b value for b: "))
    a = 0.5
    b = 0.2
    err = 0
    plt.xlabel('x')
    plt.ylabel('ax + b')
    
    #compute the error err
    for i in range(len(x)):
        err = err + (lin(x[i],a,b) - dataPoints[i])**2
    
    #pass a list and return a list
    y = []
    for i in range(len(x)):
        y.append(lin(x[i],2,3))
    
    #plot two sets of data; x and dataPoints are given *
    plt.plot(x, y, x, dataPoints, '*')
    print("x[", i, "] =", x[i], ", y[", i, "] =", y[i])
    
    print("error = ", err)
    plt.show()
    return err

x = [0, 1, 2, 3, 4]
dataPoints = [0.5, 2.0, 1.0, 1.5, 7.5]

fit(x, dataPoints)
# Out:
# x[ 4 ] = 4 , y[ 4 ] = 11
# error =  29.95
# 29.95

# %% [markdown]
# From the sample input of values a = 0.5 and b = 0.2, we can see how far the equation `y = 0.5x + 0.2` is from the data points in the list `dataPoints = [0.5, 2.0, 1.0, 1.5, 7.5]`
